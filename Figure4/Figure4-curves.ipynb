# %%
# importing libraries and set standards
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks
import statistics as stat
from scipy.integrate import odeint
from lmfit import minimize, Parameters, Parameter, report_fit

plt.rcParams['figure.figsize'] = 21, 15
plt.rcParams['xtick.labelsize']=65
plt.rcParams['ytick.labelsize']=65
plt.rcParams['ytick.right'] = plt.rcParams['ytick.labelright'] = False
plt.rcParams['ytick.left'] = plt.rcParams['ytick.labelleft'] = True
plt.rcParams.update({'figure.autolayout': False})
plt.rcParams['axes.linewidth'] = 5
plt.rcParams['font.family'] = 'Arial'

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the Excel file
df = pd.read_excel('Figure4-lowGC.xlsx')

# Extract time and data columns
time = df.iloc[:, 0] + 90
data = df.iloc[:, 1:]

# Define the columns you want to plot (by index or name), their custom labels, and colors
plot_config = [
    {"col": data.columns[1], "label": "Low GC 2", "color": "#ff8300"},
    {"col": data.columns[6], "label": "Low GC 2 + dsDNA", "color": "#ffb100"},
]

# Plot time against data
fig, ax = plt.subplots()

for cfg in plot_config:
    ax.plot(
        time / 3600,
        data[cfg["col"]],
        label=cfg["label"],
        linewidth=20,
        color=cfg["color"],
        alpha=0.6,
    )

# Axes styling
plt.title("Background DNA N200 at 0.2 µM", fontsize=60, weight='bold', pad=15)
ax.set_xlim([-0.1, 7])
ax.set_ylim([-10, 220])
ax.tick_params(axis='both', which='major', length=15, width=6)

ax.set_xlabel('Time (hours)', fontsize=65)
ax.set_ylabel('Intensity (n.u.)', fontsize=65)

# Move the legend outside the plot on the upper right
ax.legend(loc='upper left', bbox_to_anchor=(0.35, 0.35), fontsize=45, frameon=False)

# Adjust layout to make space for the legend
plt.subplots_adjust(right=0.75)

# Save and show the plot
plt.savefig('Figure4-LowGC-kinetics.svg', format='svg', dpi=300)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the Excel file
df = pd.read_excel('Figure4-Pur_Pyr.xlsx')

# Extract time and data columns
time = df.iloc[:, 0] + 90
data = df.iloc[:, 1:]

# Define the columns you want to plot (by index or name), their custom labels, and colors
plot_config = [
    {"col": data.columns[10], "label": "Pur:Pyr 1:7 C", "color": "#2ca02c"},
    {"col": data.columns[11], "label": "Pur:Pyr 1:7 C + dsDNA", "color": "#9cbf22"},
]

# Plot time against data
fig, ax = plt.subplots()

for cfg in plot_config:
    ax.plot(
        time / 3600,
        data[cfg["col"]],
        label=cfg["label"],
        linewidth=20,
        color=cfg["color"],
        alpha=0.6,
    )

# Axes styling
plt.title("Background DNA N200 at 0.2 µM", fontsize=60, weight='bold', pad=15)
ax.set_xlim([-0.1, 7])
ax.set_ylim([-10, 220])
ax.tick_params(axis='both', which='major', length=15, width=6)

ax.set_xlabel('Time (hours)', fontsize=65)
ax.set_ylabel('Intensity (n.u.)', fontsize=65)

# Move the legend outside the plot on the upper right
ax.legend(loc='upper left', bbox_to_anchor=(0.30, 0.35), fontsize=45, frameon=False)

# Adjust layout to make space for the legend
plt.subplots_adjust(right=0.75)

# Save and show the plot
plt.savefig('Figure4-Pur_Pyr-kinetics.svg', format='svg', dpi=300)
plt.show()
